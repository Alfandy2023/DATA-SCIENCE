# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Importing Dataset
NBA = pd.read_csv('nba.csv')

# %%
NBA
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# The Largest 5 values by Age 
NBA.nlargest(5,['Age'])
# Out:
#                Name                    Team  Number Position   Age Height  \
# 298      Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 304    Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# 261    Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
#
#      Weight         College     Salary
# 298   250.0     Wake Forest  5250000.0
# 304   200.0            Utah   250750.0
# 400   240.0             NaN  8500000.0
# 102   185.0             NaN   947726.0
# 261   220.0  North Carolina  4088019.0

# %%
# The Smallest 5 values by Age 
NBA.nsmallest(5,['Age'])
# Out:
#                    Name                Team  Number Position   Age Height  \
# 122        Devin Booker        Phoenix Suns     1.0       SG  19.0    6-6
# 226       Rashad Vaughn     Milwaukee Bucks    20.0       SG  19.0    6-6
# 13          James Young      Boston Celtics    13.0       SG  20.0    6-6
# 40   Kristaps Porzingis     New York Knicks     6.0       PF  20.0    7-3
# 56        Jahlil Okafor  Philadelphia 76ers     8.0        C  20.0   6-11
#
#      Weight   College     Salary
# 122   206.0  Kentucky  2127840.0
# 226   202.0      UNLV  1733040.0
# 13    215.0  Kentucky  1749840.0
# 40    240.0       NaN  4131720.0
# 56    275.0      Duke  4582680.0

# %%
# The Largest 5 values by Weight
NBA.nlargest(5,['Weight'])
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 405    Nikola Pekovic  Minnesota Timberwolves    14.0        C  30.0   6-11
# 302  Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 330      Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
# 395      Jusuf Nurkic          Denver Nuggets    23.0        C  21.0    7-0
# 188    Andre Drummond         Detroit Pistons     0.0        C  22.0   6-11
#
#      Weight      College      Salary
# 405   307.0          NaN  12100000.0
# 302   290.0          NaN   1200000.0
# 330   289.0          NaN  13500000.0
# 395   280.0          NaN   1842000.0
# 188   279.0  Connecticut   3272091.0

# %%
# The Smallest 5 values by Weight 
NBA.nsmallest(5,['Weight'])
# Out:
#                  Name                  Team  Number Position   Age Height  \
# 152      Aaron Brooks         Chicago Bulls     0.0       PG  31.0    6-0
# 263      Bryce Cotton     Memphis Grizzlies     8.0       PG  23.0    6-1
# 350     Briante Weber            Miami Heat    12.0       PG  23.0    6-2
# 359  Brandon Jennings         Orlando Magic    55.0       PG  26.0    6-1
# 286       Tim Frazier  New Orleans Pelicans     2.0       PG  25.0    6-1
#
#      Weight                College     Salary
# 152   161.0                 Oregon  2250000.0
# 263   165.0             Providence   700902.0
# 350   165.0  Virginia Commonwealth        NaN
# 359   169.0                    NaN  8344497.0
# 286   170.0             Penn State   845059.0

# %%
# The 10 largest Salary
NBA.nlargest(10,['Salary'])
# Out:
#                 Name                   Team  Number Position   Age Height  \
# 109      Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James    Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard        Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100       Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414     Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164     Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# 349      Dwyane Wade             Miami Heat     3.0       SG  34.0    6-4
# 23       Brook Lopez          Brooklyn Nets    11.0        C  28.0    7-0
#
#      Weight       College      Salary
# 109   212.0           NaN  25000000.0
# 169   250.0           NaN  22970500.0
# ...

# %%
# The 10 smallest Salary
NBA.nsmallest(10,['Salary'])
# Out:
#                        Name                  Team  Number Position   Age  \
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 92               Jeff Ayres  Los Angeles Clippers    19.0       PF  29.0
# 184           Lorenzo Brown       Detroit Pistons    17.0       PG  25.0
# 21          Sean Kilpatrick         Brooklyn Nets     6.0       SG  26.0
# 45              Tony Wroten       New York Knicks     5.0       SG  23.0
# 282      Bryce Dejean-Jones  New Orleans Pelicans    31.0       SG  23.0
#
#     Height  Weight               College    Salary
# 32     6-7   205.0                   NaN   30888.0
# 130   5-11   175.0              Missouri   55722.0
# ...
