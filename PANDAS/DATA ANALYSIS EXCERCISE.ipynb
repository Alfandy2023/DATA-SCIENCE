# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
elect = pd.read_csv('electronics.csv')

# %%
elect
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         NaN  1999       NaN      0
# 1         Portable Audio & Video         NaN  1999       NaN      0
# 2         Portable Audio & Video         NaN  1999       NaN      0
# ...

# %%
# identify each column with their respective data type 
elect.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  object
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
#  7   year        1292954 non-null  int64
#  8   user_attr   174124 non-null   object
#  9   split       1292954 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 98.6+ MB

# %%
# convert timestmp into datetime
from datetime import datetime
pd.to_datetime(elect['timestamp'])
# Out:
# 0         1999-06-13
# 1         1999-06-14
# 2         1999-06-17
# 3         1999-07-01
# 4         1999-07-06
#              ...
# 1292949   2018-09-26
# 1292950   2018-09-26
# 1292951   2018-09-26
# 1292952   2018-09-29
# 1292953   2018-10-01
# Name: timestamp, Length: 1292954, dtype: datetime64[ns]

# %%
# convert some columns from object to string
elect['brand'] = elect['brand'].astype(str)

# %%
elect
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         nan  1999       NaN      0
# 1         Portable Audio & Video         nan  1999       NaN      0
# 2         Portable Audio & Video         nan  1999       NaN      0
# ...

# %%
elect['category'] = elect['category'].astype(str)

# %%
elect
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         nan  1999       NaN      0
# 1         Portable Audio & Video         nan  1999       NaN      0
# 2         Portable Audio & Video         nan  1999       NaN      0
# ...

# %%
elect['uaer_id'] = elect['user_id'].astype(str)

# %%
elect
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split  uaer_id
# 0         Portable Audio & Video         nan  1999       NaN      0        0
# 1         Portable Audio & Video         nan  1999       NaN      0        1
# ...

# %%
# statistical summary for dataset
elect.describe()
# Out:
#             item_id       user_id        rating          year         split
# count  1.292954e+06  1.292954e+06  1.292954e+06  1.292954e+06  1.292954e+06
# mean   4.183588e+03  5.605127e+05  4.051482e+00  2.012938e+03  1.747587e-01
# std    2.525346e+03  3.342374e+05  1.379732e+00  2.643513e+00  5.506810e-01
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.999000e+03  0.000000e+00
# 25%    2.018000e+03  2.697482e+05  4.000000e+00  2.012000e+03  0.000000e+00
# 50%    3.930000e+03  5.518920e+05  5.000000e+00  2.014000e+03  0.000000e+00
# 75%    6.289000e+03  8.474858e+05  5.000000e+00  2.015000e+03  0.000000e+00
# max    9.559000e+03  1.157632e+06  5.000000e+00  2.018000e+03  2.000000e+00

# %%
# remove all non values under Rating
elect['rating'].dropna(inplace=True)
elect['rating'].drop_duplicates(inplace=True)

# %%
elect
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split  uaer_id
# 0         Portable Audio & Video         nan  1999       NaN      0        0
# 1         Portable Audio & Video         nan  1999       NaN      0        1
# ...

# %%
# check for duplicate
elect.duplicated().sum()
# Out:
# 0

# %%
# The Distribution of rating
sns.countplot(x='rating', data=elect)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
# the best year of sales
elect.groupby(['year']).sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
 # what brand sold the most in 2015
elect_2015 = elect[elect['year'] == 2015]
elect_2015.groupby('brand')['rating'].count().sort_values(ascending=False).head(5).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='brand'>

# %%
 # what brand sold the most in 2016
elect[elect['year'] == 2016].groupby('brand')['rating'].count().plot(kind='bar', width= 1.5)
# Out:
# <AxesSubplot:xlabel='brand'>

# %%
# How much sales made in 2015
elect[elect['year'] == 2015].groupby('year')['rating'].count().plot(kind='bar', color= 'green', width=0.3)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# what was the best month of sales
elect['month'] = pd.DatetimeIndex(elect['timestamp']).month
elect.groupby('month')['rating'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
# What product by category sold the most?
dataset.groupby('category')['rating'].count().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
elect.groupby(['category']).sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='category'>

# %%
# what brand sold least
elect.groupby('brand')['rating'].count().sort_values(ascending=True).head(5).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='brand'>

# %%
# percentage of sales by category of the product
elect.groupby('category')['rating'].count().sort_values(ascending=False).head(10).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='rating'>
