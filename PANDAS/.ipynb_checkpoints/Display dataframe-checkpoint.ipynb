# %%
import pandas as pd

# %%
exams = pd.read_csv('StudentsPerformance.csv')

# %%
# determine first 3 columns
exams.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
# determine the first 9 columns 
exams.head(9)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# ...

# %%
# determine the last 5 columns
exams.tail(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# determine the last 7 columns
exams.tail(7)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# ...

# %%
# To show or get shape of data. this means number of rows and colunm

# %%
exams.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6548\3527953153.py in <module>
# ----> 1 exams.shape
#
# NameError: name 'exams' is not defined

# %%
teamdata = pd.DataFrame({'team':['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'], 'points':[25, 12, 15, 14, 19, 23, 25, 29], 'assists':[5, 7, 7, 9, 12, 9, 9, 4], 'rebounds': [11, 8, 10, 6, 6, 5, 9, 12]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6548\2362189462.py in <module>
# ----> 1 teamdata = pd.DataFrame({'team':['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'], 'points':[25, 12, 15, 14, 19, 23, 25, 29], 'assists':[5, 7, 7, 9, 12, 9, 9, 4], 'rebounds': [11, 8, 10, 6, 6, 5, 9, 12]})
#
# NameError: name 'pd' is not defined

# %%
list(teamdata)
# Out:
# ['team', 'points', 'assists', 'rebounds']

# %%
# how to rename specdific colunm names
teamdata.rename(columns = {'team': 'team_name', 'points': 'points_scored'}, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6548\880979397.py in <module>
#       1 # how to rename specdific colunm names
# ----> 2 teamdata.rename(columns = {'team': 'team_name', 'points': 'points_scored'}, inplace = True)
#
# NameError: name 'teamdata' is not defined

# %%
teamdata
# Out:
#   team_name  points_scored  assists  rebounds
# 0         A             25        5        11
# 1         A             12        7         8
# 2         A             15        7        10
# 3         A             14        9         6
# 4         B             19       12         6
# 5         B             23        9         5
# 6         B             25        9         9
# 7         B             29        4        12
