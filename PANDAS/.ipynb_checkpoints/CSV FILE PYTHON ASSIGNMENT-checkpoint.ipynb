# %% [markdown]
# # import pandas as pd

# %%
import pandas as pd

# %%
# reading the csv file
mdata = pd.read_csv('Modified.csv')

# %%
mdata
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  HP  Attack  \
# 0             0    1              Bulbasaur    Grass  Poison  45      49
# 1             1    2                Ivysaur    Grass  Poison  60      62
# 2             2    3               Venusaur    Grass  Poison  80      82
# 3             3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4             4    4             Charmander     Fire     NaN  39      52
# ..          ...  ...                    ...      ...     ...  ..     ...
# 795         795  719                Diancie     Rock   Fairy  50     100
# 796         796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799         799  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# how to show all datas in one page without hidding any elwement
pd.set_option('display.max_rows',800)

# %%
mdata
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  \
# 0             0    1                  Bulbasaur     Grass    Poison   45
# 1             1    2                    Ivysaur     Grass    Poison   60
# 2             2    3                   Venusaur     Grass    Poison   80
# 3             3    3      VenusaurMega Venusaur     Grass    Poison   80
# 4             4    4                 Charmander      Fire       NaN   39
# 5             5    5                 Charmeleon      Fire       NaN   58
# 6             6    6                  Charizard      Fire    Flying   78
# 7             7    6  CharizardMega Charizard X      Fire    Dragon   78
# 8             8    6  CharizardMega Charizard Y      Fire    Flying   78
# 9             9    7                   Squirtle     Water       NaN   44
# 10           10    8                  Wartortle     Water       NaN   59
# 11           11    9                  Blastoise     Water       NaN   79
# ...

# %% [markdown]
# # ATTRIBUTES

# %%
# first attributes means shape. e.g
mdata.shape
# Out:
# (800, 13)

# %%
# second attributes means index. e.g
mdata.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
# third attributes means column. e.g
mdata.columns
# Out:
# Index(['Unnamed: 0', '#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# fouth attributes means data types of each column
mdata.dtypes
# Out:
# Unnamed: 0     int64
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# # METHODS
# IT CONTAINS HEAD, TAIL, DESCRIBE AND INFO

# %%
# (HEAD): SHOWING FIRST 5 COLUMNS
mdata.head()
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  HP  Attack  Defense  \
# 0           0  1              Bulbasaur  Grass  Poison  45      49       49
# 1           1  2                Ivysaur  Grass  Poison  60      62       63
# 2           2  3               Venusaur  Grass  Poison  80      82       83
# 3           3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4           4  4             Charmander   Fire     NaN  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
mdata.head(11)
# Out:
#     Unnamed: 0  #                       Name Type 1  Type 2  HP  Attack  \
# 0            0  1                  Bulbasaur  Grass  Poison  45      49
# 1            1  2                    Ivysaur  Grass  Poison  60      62
# 2            2  3                   Venusaur  Grass  Poison  80      82
# 3            3  3      VenusaurMega Venusaur  Grass  Poison  80     100
# 4            4  4                 Charmander   Fire     NaN  39      52
# 5            5  5                 Charmeleon   Fire     NaN  58      64
# 6            6  6                  Charizard   Fire  Flying  78      84
# 7            7  6  CharizardMega Charizard X   Fire  Dragon  78     130
# 8            8  6  CharizardMega Charizard Y   Fire  Flying  78     104
# 9            9  7                   Squirtle  Water     NaN  44      48
# 10          10  8                  Wartortle  Water     NaN  59      63
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# TAIL. SHOW FIRST 5 COLUMNS
mdata.tail()
# Out:
#      Unnamed: 0    #                 Name   Type 1 Type 2  HP  Attack  \
# 795         795  719              Diancie     Rock  Fairy  50     100
# 796         796  719  DiancieMega Diancie     Rock  Fairy  50     160
# 797         797  720  HoopaHoopa Confined  Psychic  Ghost  80     110
# 798         798  720   HoopaHoopa Unbound  Psychic   Dark  80     160
# 799         799  721            Volcanion     Fire  Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True

# %%
mdata.head(15)
# Out:
#     Unnamed: 0   #                       Name Type 1  Type 2  HP  Attack  \
# 0            0   1                  Bulbasaur  Grass  Poison  45      49
# 1            1   2                    Ivysaur  Grass  Poison  60      62
# 2            2   3                   Venusaur  Grass  Poison  80      82
# 3            3   3      VenusaurMega Venusaur  Grass  Poison  80     100
# 4            4   4                 Charmander   Fire     NaN  39      52
# 5            5   5                 Charmeleon   Fire     NaN  58      64
# 6            6   6                  Charizard   Fire  Flying  78      84
# 7            7   6  CharizardMega Charizard X   Fire  Dragon  78     130
# 8            8   6  CharizardMega Charizard Y   Fire  Flying  78     104
# 9            9   7                   Squirtle  Water     NaN  44      48
# 10          10   8                  Wartortle  Water     NaN  59      63
# 11          11   9                  Blastoise  Water     NaN  79      83
# ...

# %%
# showing the description of dataframe
mdata.describe()
# Out:
#        Unnamed: 0           #          HP      Attack     Defense     Sp. Atk  \
# count    800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean     399.5000  362.813750   69.258750   79.001250   73.842500   72.820000
# std      231.0844  208.343798   25.534669   32.457366   31.183501   32.722294
# min        0.0000    1.000000    1.000000    5.000000    5.000000   10.000000
# 25%      199.7500  184.750000   50.000000   55.000000   50.000000   49.750000
# 50%      399.5000  364.500000   65.000000   75.000000   70.000000   65.000000
# 75%      599.2500  539.250000   80.000000  100.000000   90.000000   95.000000
# max      799.0000  721.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# showing info of the dataframe
mdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  800 non-null    int64
#  1   #           800 non-null    int64
#  2   Name        800 non-null    object
#  3   Type 1      800 non-null    object
#  4   Type 2      414 non-null    object
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# # FUNCTIONS
# IT CONTAINS LEN, INDEX, TYPE AND ROUND

# %%
# the first function is len. determine the len of the dataframe
len(mdata)
# Out:
# 800

# %%
# second function is index (highest index and lowest index)
max(mdata.index)
# Out:
# 799

# %%
min(mdata.index)
# Out:
# 0

# %%
# thierd function is type
type(mdata)
# Out:
# pandas.core.frame.DataFrame

# %%
# fouth function is round
round(mdata, 3)
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  \
# 0             0    1                  Bulbasaur     Grass    Poison   45
# 1             1    2                    Ivysaur     Grass    Poison   60
# 2             2    3                   Venusaur     Grass    Poison   80
# 3             3    3      VenusaurMega Venusaur     Grass    Poison   80
# 4             4    4                 Charmander      Fire       NaN   39
# 5             5    5                 Charmeleon      Fire       NaN   58
# 6             6    6                  Charizard      Fire    Flying   78
# 7             7    6  CharizardMega Charizard X      Fire    Dragon   78
# 8             8    6  CharizardMega Charizard Y      Fire    Flying   78
# 9             9    7                   Squirtle     Water       NaN   44
# 10           10    8                  Wartortle     Water       NaN   59
# 11           11    9                  Blastoise     Water       NaN   79
# ...

# %%
country_dict = [{'name':'India', 'capital':'New Delhi', 'dialing_code':91}, {'name':'USA', 'capital':'Washington D.C', 'dialing_code':1}, {'name':'UK', 'capital':'London', 'dialing_code':44}, {'name':'canada', 'capital':'Ottawa', 'dailing_code':1}]

# %%
country_dict
# Out:
# [{'name': 'India', 'capital': 'New Delhi', 'dialing_code': 91},
#  {'name': 'USA', 'capital': 'Washington D.C', 'dialing_code': 1},
#  {'name': 'UK', 'capital': 'London', 'dialing_code': 44},
#  {'name': 'canada', 'capital': 'Ottawa', 'dailing_code': 1}]

# %%
country_dict = pd.DataFrame(country_dict)

# %%
country_dict
# Out:
#      name         capital  dialing_code  dailing_code
# 0   India       New Delhi          91.0           NaN
# 1     USA  Washington D.C           1.0           NaN
# 2      UK          London          44.0           NaN
# 3  canada          Ottawa           NaN           1.0

# %% [markdown]
# # MATHS OPERATIONS

# %%
import pandas as pd

# %%
# reading the csv file
mdata = pd.read_csv('Modified.csv')

# %%
mdata
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  HP  Attack  \
# 0             0    1              Bulbasaur    Grass  Poison  45      49
# 1             1    2                Ivysaur    Grass  Poison  60      62
# 2             2    3               Venusaur    Grass  Poison  80      82
# 3             3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4             4    4             Charmander     Fire     NaN  39      52
# ..          ...  ...                    ...      ...     ...  ..     ...
# 795         795  719                Diancie     Rock   Fairy  50     100
# 796         796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799         799  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# how to show all datas in one page without hidding any elwement
pd.set_option('display.max_rows',800)
mdata
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  \
# 0             0    1                  Bulbasaur     Grass    Poison   45
# 1             1    2                    Ivysaur     Grass    Poison   60
# 2             2    3                   Venusaur     Grass    Poison   80
# 3             3    3      VenusaurMega Venusaur     Grass    Poison   80
# 4             4    4                 Charmander      Fire       NaN   39
# 5             5    5                 Charmeleon      Fire       NaN   58
# 6             6    6                  Charizard      Fire    Flying   78
# 7             7    6  CharizardMega Charizard X      Fire    Dragon   78
# 8             8    6  CharizardMega Charizard Y      Fire    Flying   78
# 9             9    7                   Squirtle     Water       NaN   44
# 10           10    8                  Wartortle     Water       NaN   59
# 11           11    9                  Blastoise     Water       NaN   79
# ...

# %%
#select a column and calculate total sum
mdata['Speed'].sum()
# Out:
# 54622

# %%
#select a column and calculate total sum
mdata['Generation'].sum()
# Out:
# 2659

# %%
# calculate them with describe function
mdata.describe()
# Out:
#        Unnamed: 0           #          HP      Attack     Defense     Sp. Atk  \
# count    800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean     399.5000  362.813750   69.258750   79.001250   73.842500   72.820000
# std      231.0844  208.343798   25.534669   32.457366   31.183501   32.722294
# min        0.0000    1.000000    1.000000    5.000000    5.000000   10.000000
# 25%      199.7500  184.750000   50.000000   55.000000   50.000000   49.750000
# 50%      399.5000  364.500000   65.000000   75.000000   70.000000   65.000000
# 75%      599.2500  539.250000   80.000000  100.000000   90.000000   95.000000
# max      799.0000  721.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# calculate count, mean, std, max and min

# %%
# calculate count
mdata['Speed'].count()
# Out:
# 800

# %%
# calculate mean
mdata['Speed'].mean()
# Out:
# 68.2775

# %%
# calculate std
mdata['Speed'].std()
# Out:
# 29.06047371716149

# %%
# calculate max
mdata['Speed'].max()
# Out:
# 180

# %%
# calculate min
mdata['Speed'].min()
# Out:
# 5

# %%
# calculate the sum in a row
mdata['Speed'] + mdata['Generation'] + mdata['Defense']
# Out:
# 0       95
# 1      124
# 2      164
# 3      204
# 4      109
# 5      139
# 6      179
# 7      212
# 8      179
# 9      109
# 10     139
# 11     179
# 12     199
# 13      81
# 14      86
# 15     121
# 16      81
# 17      86
# 18     116
# 19     186
# 20      97
# 21     127
# 22     177
# 23     202
# 24     108
# 25     158
# 26     101
# 27     166
# 28     100
# 29     150
# 30     131
# 31     166
# 32     126
# 33     176
# 34      94
# 35     124
# 36     164
# 37      91
# 38     123
# 39     163
# 40      84
# 41     134
# 42     106
# 43     176
# 44      41
# 45      91
# 46      91
# 47     161
# 48      86
# 49     111
# 50     136
# 51      81
# 52     111
# 53      96
# 54     151
# 55     121
# 56     171
# 57     126
# 58     176
# 59     104
# 60     164
# 61     106
# 62     156
# 63     106
# 64     176
# 65     131
# 66     156
# 67     166
# 68     106
# 69     136
# 70     166
# 71     216
# 72      86
# 73     116
# 74     136
# 75      76
# ...

# %%
# calculate the average and show it in the frame
mdata['average'] = (mdata['Defense'] + mdata['Speed'] + mdata['Generation'])/3

# %%
mdata
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  \
# 0             0    1                  Bulbasaur     Grass    Poison   45
# 1             1    2                    Ivysaur     Grass    Poison   60
# 2             2    3                   Venusaur     Grass    Poison   80
# 3             3    3      VenusaurMega Venusaur     Grass    Poison   80
# 4             4    4                 Charmander      Fire       NaN   39
# 5             5    5                 Charmeleon      Fire       NaN   58
# 6             6    6                  Charizard      Fire    Flying   78
# 7             7    6  CharizardMega Charizard X      Fire    Dragon   78
# 8             8    6  CharizardMega Charizard Y      Fire    Flying   78
# 9             9    7                   Squirtle     Water       NaN   44
# 10           10    8                  Wartortle     Water       NaN   59
# 11           11    9                  Blastoise     Water       NaN   79
# ...

# %% [markdown]
# # THE VALUE AND COUNT METHODS

# %%
# DETERMINE THE COUNT
mdata['Type 1'].count()
# Out:
# 800

# %%
# determine the value
mdata['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# # DETERMING OF THE RELATIVE FREQUENCY

# %%
# determine the relative frequency. This means, (divide the total value by grand total value )

# %%
# detremine the relative frequency
mdata['Type 1'].value_counts(normalize=True)
# Out:
# Water       0.14000
# Normal      0.12250
# Grass       0.08750
# Bug         0.08625
# Psychic     0.07125
# Fire        0.06500
# Electric    0.05500
# Rock        0.05500
# Dragon      0.04000
# Ground      0.04000
# Ghost       0.04000
# Dark        0.03875
# Poison      0.03500
# Steel       0.03375
# Fighting    0.03375
# Ice         0.03000
# Fairy       0.02125
# Flying      0.00500
# Name: Type 1, dtype: float64

# %%
# determine the value
mdata['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
# determine the relative frequency
mdata['Type 2'].value_counts(normalize=True)
# Out:
# Flying      0.234300
# Ground      0.084541
# Poison      0.082126
# Psychic     0.079710
# Fighting    0.062802
# Grass       0.060386
# Fairy       0.055556
# Steel       0.053140
# Dark        0.048309
# Dragon      0.043478
# Water       0.033816
# Ghost       0.033816
# Ice         0.033816
# Rock        0.033816
# Fire        0.028986
# Electric    0.014493
# Normal      0.009662
# Bug         0.007246
# Name: Type 2, dtype: float64

# %%
 # DETERMINE THE RELATIVE REQUENCY AND CONVERT TO 2 DECIMAL PLACE
mdata['Type 1'].value_counts(normalize=True).round(2)
# Out:
# Water       0.14
# Normal      0.12
# Grass       0.09
# Bug         0.09
# Psychic     0.07
# Fire        0.06
# Electric    0.06
# Rock        0.06
# Dragon      0.04
# Ground      0.04
# Ghost       0.04
# Dark        0.04
# Poison      0.04
# Steel       0.03
# Fighting    0.03
# Ice         0.03
# Fairy       0.02
# Flying      0.00
# Name: Type 1, dtype: float64

# %%
# determine the relative frequency
mdata['Type 2'].value_counts(normalize=True). round(2)
# Out:
# Flying      0.23
# Ground      0.08
# Poison      0.08
# Psychic     0.08
# Fighting    0.06
# Grass       0.06
# Fairy       0.06
# Steel       0.05
# Dark        0.05
# Dragon      0.04
# Water       0.03
# Ghost       0.03
# Ice         0.03
# Rock        0.03
# Fire        0.03
# Electric    0.01
# Normal      0.01
# Bug         0.01
# Name: Type 2, dtype: float64

# %% [markdown]
# #  SORTING OF DATAFRAME

# %%
# sort by 0ne column in ascending order
mdata.sort_values('Speed')
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  \
# 495         495  446                   Munchlax    Normal       NaN  135
# 230         230  213                    Shuckle       Bug      Rock   20
# 658         658  597                  Ferroseed     Grass     Steel   44
# 486         486  438                     Bonsly      Rock       NaN   50
# 359         359  328                   Trapinch    Ground       NaN   45
# 289         289  266                    Silcoon       Bug       NaN   50
# 651         651  590                    Foongus     Grass    Poison   69
# 209         209  194                     Wooper     Water    Ground   55
# 85           85   79                   Slowpoke     Water   Psychic   90
# 187         187  173                     Cleffa     Fairy       NaN   50
# 188         188  174                  Igglybuff    Normal     Fairy   90
# 583         583  524                 Roggenrola      Rock       NaN   55
# ...

# %%
# sort by 0ne column in descending order
mdata.sort_values('Speed', ascending=False)
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  \
# 431         431  386          DeoxysSpeed Forme   Psychic       NaN   50
# 315         315  291                    Ninjask       Bug    Flying   61
# 428         428  386         DeoxysNormal Forme   Psychic       NaN   50
# 154         154  142  AerodactylMega Aerodactyl      Rock    Flying   80
# 71           71   65      AlakazamMega Alakazam   Psychic       NaN   55
# 429         429  386         DeoxysAttack Forme   Psychic       NaN   50
# 19           19   15      BeedrillMega Beedrill       Bug    Poison   65
# 275         275  254      SceptileMega Sceptile     Grass    Dragon   70
# 678         678  617                   Accelgor       Bug       NaN   80
# 164         164  150        MewtwoMega Mewtwo Y   Psychic       NaN  106
# 109         109  101                  Electrode  Electric       NaN   60
# 476         476  428        LopunnyMega Lopunny    Normal  Fighting   65
# ...

# %%
# sort multiple columns in ascecending order
mdata.sort_values(['HP', 'Defense','Attack','Speed','Generation'])
# Out:
#      Unnamed: 0    #       Name    Type 1 Type 2   HP  Attack  Defense  \
# 316         316  292   Shedinja       Bug  Ghost    1      90       45
# 55           55   50    Diglett    Ground    NaN   10      55       25
# 186         186  172      Pichu  Electric    NaN   20      40       15
# 381         381  349     Feebas     Water    NaN   20      15       20
# 487         487  439   Mime Jr.   Psychic  Fairy   20      25       45
# ..          ...  ...        ...       ...    ...  ...     ...      ...
# 655         655  594  Alomomola     Water    NaN  165      75       80
# 351         351  321    Wailord     Water    NaN  170      90       45
# 217         217  202  Wobbuffet   Psychic    NaN  190      33       58
# 121         121  113    Chansey    Normal    NaN  250       5        5
# 261         261  242    Blissey    Normal    NaN  255      10       10
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 316       30       30     40           3      False
# ...

# %%
# sort in descending order by multiple columns and update dataframe
mdata.sort_values(['Speed', 'Attack'],ascending=False)
mdata
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2   HP  Attack  \
# 495         495  446               Munchlax   Normal     NaN  135      85
# 230         230  213                Shuckle      Bug    Rock   20      10
# 658         658  597              Ferroseed    Grass   Steel   44      50
# 486         486  438                 Bonsly     Rock     NaN   50      80
# 359         359  328               Trapinch   Ground     NaN   45     100
# ..          ...  ...                    ...      ...     ...  ...     ...
# 429         429  386     DeoxysAttack Forme  Psychic     NaN   50     180
# 71           71   65  AlakazamMega Alakazam  Psychic     NaN   55      50
# 428         428  386     DeoxysNormal Forme  Psychic     NaN   50     150
# 315         315  291                Ninjask      Bug  Flying   61      90
# 431         431  386      DeoxysSpeed Forme  Psychic     NaN   50      95
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
mdata
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  HP  Attack  \
# 0             0    1              Bulbasaur    Grass  Poison  45      49
# 1             1    2                Ivysaur    Grass  Poison  60      62
# 2             2    3               Venusaur    Grass  Poison  80      82
# 3             3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4             4    4             Charmander     Fire     NaN  39      52
# ..          ...  ...                    ...      ...     ...  ..     ...
# 795         795  719                Diancie     Rock   Fairy  50     100
# 796         796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799         799  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
