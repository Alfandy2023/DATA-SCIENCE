# %%
import pandas as pd

# %% [markdown]
# # PIVOT ()

# %%
# READ AND SHOW THE DATAFRAME WITH ISO (INDUSRIAL STANDARD FOR ORGANISATION)
gdpdata = pd.read_csv('gdp.csv', encoding="ISO-8859-1")

# %%
gdpdata
# Out:
#       unid wbid      country  year        SES       gdppc  yrseduc  popshare
# 0        4  AFG  Afghanistan  1970   3.474212   709.00000      NaN  0.003097
# 1        4  AFG  Afghanistan  1920  26.968016   731.75677      NaN  0.003245
# 2        4  AFG  Afghanistan  1990   1.269530   604.00000      NaN  0.002347
# 3        4  AFG  Afghanistan  1960  15.763076   739.00000      NaN  0.003039
# 4        4  AFG  Afghanistan  2000   2.061114   565.00000      NaN  0.003309
# ...    ...  ...          ...   ...        ...         ...      ...       ...
# 2081   716  ZWE     Zimbabwe  1940  52.746567   813.00000      NaN  0.001113
# 2082   716  ZWE     Zimbabwe  2010  27.091389  1388.97300      NaN  0.002074
# 2083   716  ZWE     Zimbabwe  1990  59.110970  2526.07230      NaN  0.002039
# 2084   716  ZWE     Zimbabwe  1900  54.722645   601.00000      NaN  0.000996
# 2085   716  ZWE     Zimbabwe  1960  53.811077   938.00000      NaN  0.001268
#
# [2086 rows x 8 columns]

# %%
# reshape the dataframe with .pivot() using year as our index
gdpdata.pivot(index='year', columns='country', values='popshare')
# Out:
# country  Afghanistan   Albania   Algeria    Angola  Argentina   Armenia  \
# year
# 1880        0.003271  0.000477  0.002995  0.001390   0.001855  0.000508
# 1890        0.003255  0.000481  0.003031  0.001417   0.002236  0.000502
# 1900        0.003245  0.000493  0.003064  0.001438   0.002890  0.000497
# 1910        0.003178  0.000494  0.003039  0.001428   0.003864  0.000483
# 1920        0.003245  0.000489  0.003219  0.001524   0.004646  0.000499
# 1930        0.003259  0.000468  0.003361  0.001587   0.005666  0.000512
# 1940        0.003226  0.000468  0.003433  0.001607   0.006099  0.000523
# 1950        0.003302  0.000497  0.003603  0.001668   0.006948  0.000549
# 1960        0.003039  0.000544  0.003759  0.001781   0.006967  0.000631
# 1970        0.003097  0.000595  0.004052  0.001755   0.006677  0.000701
# 1980        0.003057  0.000618  0.004475  0.001900   0.006504  0.000717
# 1990        0.002347  0.000639  0.005039  0.002164   0.006365  0.000689
# ...

# %%
# reshape the dataframe with .pivot() using country as our index
gdpdata.pivot(index='country', columns='year', values='popshare')
# Out:
# year             1880      1890      1900      1910      1920      1930  \
# country
# Afghanistan  0.003271  0.003255  0.003245  0.003178  0.003245  0.003259
# Albania      0.000477  0.000481  0.000493  0.000494  0.000489  0.000468
# Algeria      0.002995  0.003031  0.003064  0.003039  0.003219  0.003361
# Angola       0.001390  0.001417  0.001438  0.001428  0.001524  0.001587
# Argentina    0.001855  0.002236  0.002890  0.003864  0.004646  0.005666
# ...               ...       ...       ...       ...       ...       ...
# Venezuela    0.001400  0.001473  0.001565  0.001585  0.001569  0.001572
# Vietnam      0.009020  0.009687  0.010267  0.010583  0.010736  0.010526
# Yemen        0.002111  0.002018  0.001939  0.001839  0.001870  0.001891
# Zambia       0.000862  0.000879  0.000891  0.000885  0.000945  0.000984
# Zimbabwe     0.000963  0.000982  0.000996  0.000990  0.001056  0.001100
#
# year             1940      1950      1960      1970      1980      1990  \
# country
# ...

# %% [markdown]
# # PIVOT TABLE

# %%
# read and show the dataset
salesdata = pd.read_excel('supermarket_sales.xlsx')

# %%
salesdata
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# make a pivot table and add on agrregate function using one column and one decimal place
salesdata.pivot_table(index='Gender', aggfunc='sum').round(1)
# Out:
#         Quantity  Rating  Tax 5%     Total  Unit price      cogs  \
# Gender
# Female      2869  3489.2  7994.4  167882.9     27687.2  159888.5
# Male        2641  3483.5  7384.9  155083.8     27984.9  147698.9
#
#         gross income  gross margin percentage
# Gender
# Female        7994.4                   2385.7
# Male          7384.9                   2376.2

# %%
# # make a pivot table and add on agrregate function using multiple columns and two decimal places.
salesdata.pivot_table(index='Gender', values=['Quantity', 'Total'], aggfunc='sum').round(2)
# Out:
#         Quantity      Total
# Gender
# Female      2869  167882.92
# Male        2641  155083.82

# %%
# # make a pivot table and add on more  agrregate function using multiple columns and two decimal places.
salesdata.pivot_table(index='Gender', values=['Quantity', 'Total'], aggfunc=['sum','max', 'mean', 'std', 'median', 'count']).round(2)
# Out:
#             sum                 max              mean              std  \
#        Quantity      Total Quantity    Total Quantity   Total Quantity
# Gender
# Female     2869  167882.92       10  1042.65     5.73  335.10     2.89
# Male       2641  155083.82       10  1039.29     5.29  310.79     2.95
#
#                  median            count
#          Total Quantity   Total Quantity Total
# Gender
# Female  249.32        6  272.58      501   501
# Male    242.02        5  244.23      499   499

# %%
# make a pivot tables that will determine how much male and female spend in each categories
salesdata.pivot_table(index='Gender', columns='Product line', values='Total', aggfunc='sum').round(1)
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                       27102.0              30437.4             33170.9
# Male                         27235.5              23868.5             22973.9
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                  18561.0             30036.9            28574.7
# Male                    30632.8             23825.0            26548.1
